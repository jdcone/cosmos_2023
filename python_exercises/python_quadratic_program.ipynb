# %% [markdown]
# # Program to solve and plot the quadratic equation
#
#
# This example is more complicated and includes a matplollib plot. Your task is to fill out the cell below with the code required to solve the quadratic equation. Below are some hints/thoughts on how to do this.
#
#
# If you get totally stuck, the solution is provided in the code cell at the bottom of the notebook. Before looking at solution, I suggest you give it a reasonable try on your own first !!
#
#
# ***
# ***
#
#
# Inputs: a, b, c coefficients for the quadratic equation:
#
# > $ax^2  + bx + c = 0$
#
# Outputs:
#
# >   Two real roots: root1,root2
#
# To solve quadratic equation, use the quadratic formula:
#
#
# > $x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}$
#
# If we assign $\sqrt{b^2-4ac}$ to a variable called radical, in python the formulas are:
#
# > $radical = \sqrt{b^2-4ac}$
#
# > $root1  = ( -b + radical)/2a$
#
# > $root2  = ( -b - radical)/2a$
#
#
#  Of course, we first have to check if radical < 0:
#
#
# > If so, we print 'No real roots exist' and exit the program.
#
#
#  Sample1 input and output: Real roots exist
# ```
# Enter value for a :1
# Enter value for b :2
# Enter value for c :1
#
#  For quadratic equation :
#  1.0 * x**2 + 2.0 *x  + 1.0 = 0
#
#  Real roots are: -1.0 and -1.0
# ```
# ​
#  Sample2 input and output: No real roots exist
# ```
# Enter value for a :1
# Enter value for b :2
# Enter value for c :8
#
#  For quadratic equation :
#  1.0 * x**2 + 2.0 *x  + 8.0 = 0
#
#  No real roots exist
# ```

# %%
# Allow plot to appear in notebook
# %matplotlib inline

# %%
#  Program solves quadratic equation:
#  Inputs: a, b, c for
#        ax**2  + bx + c = 0  
#  Outputs: Two real roots     
#
import sys
import numpy as np
import matplotlib.pyplot as plt

#   Input coefficients a, b, c   
a = float(input('Enter value for a :'))
b = float(input('Enter value for b :'))
c = float(input('Enter value for c :')) 

#  Print quadratic equation: 
print('\n\n')          # Creates two line breaks before output
print (' For quadratic equation : ')
print (f' {a} * x**2 + {b} *x  + {c} = 0') 


#  Solve equation
 
#######################################################################
#   YOUR CODE GOES HERE
#        Check for real roots ( radical >= 0)
#        Use np.sqrt() function
#        if roots not real:
#               print message and sys.exit(0) (stops program)
#        else if roots are real:
#               compute and print them , and continue on to the plot  
#######################################################################




#  Plot quadratic equation
f = lambda x: a*x**2 + b*x + c 

xlim1 = min(root1,root2) -5
xlim2 = max(root1,root2) +5 
xvalues = np.linspace(xlim1,xlim2,500)
yvalues = np.array([ f(x)  for x in xvalues])
plt.plot(xvalues, yvalues, 'b-')
plt.axhline(0, color='black', lw=1)  #  line on x-axis
plt.axvline(0, color='black', lw=1)  #  line on y axis
plt.grid(True)                       #  Adds grid lines
plt.title('Plot of quadratic equation')
plt.show()
# Additional challenge:
#   Add logic to deal with imaginary (non-real) roots.

# %% [markdown]
# # Challenge Exercise
#
#
# If you get this done quickly, as a challenge add the following logic to the program:
#
#
# > Add logic to deal with and print **imaginary** (non-real) roots.
#
#
#
# > **Imaginary** roots can be expressed as:  a + bi (where a is real part and b is imaginary part)
#
#
# > Note: if roots are imaginary, we can't plot them on ordinary x-y graph (skip plot!)
